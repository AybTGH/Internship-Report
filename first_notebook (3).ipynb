# %% [markdown]
# ### Connect to AWS S3

# %%
import boto3
import pandas as pd
# Let's use Amazon S3
s3 = boto3.client('s3')

# %% [markdown]
# ### Test

# %%
path = 's3://ayoub-s3-bucket/DS.csv'
df = pd.read_csv(path,delimiter=';')
df.head()
# Out:
#       AUD     EUR     NZD     GBP     CAD
# 0  1.5172  0.9847  1.9033  0.6146  1.4465
# 1  1.5239  0.9700  1.9238  0.6109  1.4518
# 2  1.5267  0.9676  1.9339  0.6092  1.4518
# 3  1.5291  0.9686  1.9436  0.6070  1.4571
# 4  1.5272  0.9714  1.9380  0.6104  1.4505

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

S3 = boto3.resource('s3')
bucket = S3.Bucket('ayoub-s3-bucket')
img=mpimg.imread('vid_5_400.jpg')
imgplot = plt.imshow(img)

# %% [markdown]
# ### Car Detection with YOLO

# %%
import os
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
import pandas as pd
import PIL
from PIL import ImageFont, ImageDraw, Image
import tensorflow as tf

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 9>()
#       7 import PIL
#       8 from PIL import ImageFont, ImageDraw, Image
# ----> 9 import tensorflow as tf
#      11 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
path ='s3://ayoub-s3-bucket/data/'

#img = cv2.imread('s3://ayoub-s3-bucket/data/training_images/vid_4_1000.jpg', 1) 
#plt.imshow(img)

# %%
import matplotlib.image as mpimg
for img in os.listdir("/content/train"): 
    image = mpimg.imread(path)
    plt.imshow(image)
    plt.show()

# %%
pip install tensorflow
# Out:
# ...
#      |████████████████▎               | 260.1 MB 13.3 MB/s eta 0:00:19ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device            | 8.0 MB 23.1 MB/s eta 0:00:22     |█                               | 14.3 MB 23.1 MB/s eta 0:00:22     |█▍                              | 22.7 MB 23.1 MB/s eta 0:00:22     |██                              | 33.3 MB 23.1 MB/s eta 0:00:21     |██▏                             | 35.4 MB 23.1 MB/s eta 0:00:21     |██▍                             | 37.5 MB 23.1 MB/s eta 0:00:21     |██▉                             | 45.4 MB 18.0 MB/s eta 0:00:26     |███                             | 47.6 MB 18.0 MB/s eta 0:00:26     |███                             | 49.6 MB 18.0 MB/s eta 0:00:26     |███▏                            | 50.5 MB 18.0 MB/s eta 0:00:26     |████                            | 64.4 MB 18.0 MB/s eta 0:00:25     |████▎                           | 67.7 MB 18.0 MB/s eta 0:00:25     |█████▎                          | 
# ...

# %%
pip install
